# %% [markdown]
# <a href="https://colab.research.google.com/github/rea-sna/ProgrammingBasics/blob/main/pragramming_7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from graphviz import Digraph
from PIL import Image

# %%
def kaidan(n):
  if n == 1:
    return 1
  if n == 2:
    return 2
  return kaidan(n-1)+kaidan(n-2)

# %%
kaidan(10)
# Out:
# 89

# %%
def kaidan_g(n, g, nodes, parent=None):
  index = str(len(nodes))
  nodes.append(index)
  g.node(index, str(n))

  if parent is not None:
    g.edge(index, parent)

  if n in (1, 2):
    return
  kaidan_g(n-1, g, nodes, index)
  kaidan_g(n-2, g, nodes, index)

# %%
n = 8
graph = Digraph(format='png')
graph.attr(size="10,10")
kaidan_g(n, graph, [])
graph.render("test")
Image.open("test.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=960x388>
